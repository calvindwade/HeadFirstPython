# %%
suits = ["Clubs", "Spades", "Hearts", "Diamonds"]
faces = ["Jack", "Queen", "King", "Ace"]
numbered = [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
import random

# %%
def draw():
    which_suit = random.choice(suits)
    which_type = random.choice([faces, numbered])
    which_card = random.choice(which_type)
    return which_card, "of", which_suit

# %%
draw()
# Out:
# ('Jack', 'of', 'Hearts')

# %%
for n in range(500):
    card = draw()
    print(f"{n} -> {card}")
# Out:
# 0 -> ('Queen', 'of', 'Hearts')
# 1 -> ('Ace', 'of', 'Clubs')
# 2 -> (3, 'of', 'Hearts')
# 3 -> (9, 'of', 'Clubs')
# 4 -> ('King', 'of', 'Spades')
# 5 -> ('Ace', 'of', 'Hearts')
# 6 -> ('Queen', 'of', 'Diamonds')
# 7 -> ('King', 'of', 'Hearts')
# 8 -> ('King', 'of', 'Hearts')
# 9 -> ('Jack', 'of', 'Clubs')
# 10 -> ('King', 'of', 'Spades')
# 11 -> ('Ace', 'of', 'Diamonds')
# 12 -> (8, 'of', 'Spades')
# 13 -> ('King', 'of', 'Diamonds')
# 14 -> (4, 'of', 'Spades')
# 15 -> (9, 'of', 'Spades')
# 16 -> ('King', 'of', 'Spades')
# 17 -> ('Queen', 'of', 'Spades')
# 18 -> (8, 'of', 'Clubs')
# 19 -> ('Queen', 'of', 'Spades')
# 20 -> ('Jack', 'of', 'Clubs')
# 21 -> ('Queen', 'of', 'Hearts')
# 22 -> (7, 'of', 'Spades')
# 23 -> (3, 'of', 'Clubs')
# 24 -> ('King', 'of', 'Spades')
# 25 -> ('Jack', 'of', 'Hearts')
# 26 -> (4, 'of', 'Diamonds')
# 27 -> (3, 'of', 'Hearts')
# 28 -> ('King', 'of', 'Clubs')
# 29 -> ('Ace', 'of', 'Hearts')
# 30 -> ('Jack', 'of', 'Spades')
# 31 -> ('King', 'of', 'Diamonds')
# 32 -> (9, 'of', 'Spades')
# 33 -> ('Jack', 'of', 'Spades')
# 34 -> (9, 'of', 'Clubs')
# 35 -> ('Jack', 'of', 'Hearts')
# 36 -> (2, 'of', 'Hearts')
# 37 -> (8, 'of', 'Clubs')
# 38 -> (2, 'of', 'Spades')
# 39 -> (7, 'of', 'Clubs')
# 40 -> (6, 'of', 'Spades')
# 41 -> (4, 'of', 'Spades')
# 42 -> (6, 'of', 'Hearts')
# 43 -> ('Queen', 'of', 'Spades')
# 44 -> ('Queen', 'of', 'Hearts')
# 45 -> ('Ace', 'of', 'Clubs')
# 46 -> ('Jack', 'of', 'Hearts')
# 47 -> ('King', 'of', 'Spades')
# 48 -> ('Queen', 'of', 'Spades')
# 49 -> ('Ace', 'of', 'Diamonds')
# 50 -> ('Queen', 'of', 'Clubs')
# 51 -> ('Ace', 'of', 'Diamonds')
# 52 -> ('Jack', 'of', 'Diamonds')
# 53 -> (5, 'of', 'Spades')
# 54 -> ('Jack', 'of', 'Clubs')
# 55 -> (6, 'of', 'Spades')
# 56 -> (3, 'of', 'Hearts')
# 57 -> ('King', 'of', 'Spades')
# 58 -> (9, 'of', 'Hearts')
# 59 -> ('Queen', 'of', 'Diamonds')
# 60 -> ('Jack', 'of', 'Hearts')
# 61 -> (5, 'of', 'Clubs')
# 62 -> ('Ace', 'of', 'Spades')
# 63 -> (4, 'of', 'Diamonds')
# 64 -> ('King', 'of', 'Clubs')
# 65 -> (8, 'of', 'Spades')
# 66 -> (9, 'of', 'Spades')
# 67 -> ('Jack', 'of', 'Spades')
# 68 -> (10, 'of', 'Diamonds')
# 69 -> (3, 'of', 'Spades')
# 70 -> ('Queen', 'of', 'Diamonds')
# 71 -> (6, 'of', 'Hearts')
# 72 -> (9, 'of', 'Diamonds')
# 73 -> (5, 'of', 'Diamonds')
# 74 -> (6, 'of', 'Diamonds')
# 75 -> (3, 'of', 'Spades')
# 76 -> (8, 'of', 'Diamonds')
# 77 -> (3, 'of', 'Clubs')
# 78 -> (6, 'of', 'Diamonds')
# 79 -> ('Queen', 'of', 'Clubs')
# 80 -> (9, 'of', 'Diamonds')
# 81 -> (9, 'of', 'Hearts')
# 82 -> (9, 'of', 'Hearts')
# 83 -> (4, 'of', 'Diamonds')
# 84 -> ('Jack', 'of', 'Hearts')
# 85 -> ('Queen', 'of', 'Clubs')
# 86 -> ('Jack', 'of', 'Clubs')
# 87 -> ('Jack', 'of', 'Hearts')
# 88 -> ('King', 'of', 'Hearts')
# 89 -> (9, 'of', 'Diamonds')
# 90 -> ('King', 'of', 'Diamonds')
# 91 -> (2, 'of', 'Diamonds')
# 92 -> (2, 'of', 'Hearts')
# 93 -> ('Jack', 'of', 'Spades')
# 94 -> (3, 'of', 'Diamonds')
# 95 -> (9, 'of', 'Hearts')
# 96 -> ('Jack', 'of', 'Diamonds')
# 97 -> ('King', 'of', 'Clubs')
# 98 -> ('Queen', 'of', 'Clubs')
# 99 -> (8, 'of', 'Spades')
# 100 -> ('Queen', 'of', 'Hearts')
# 101 -> ('Jack', 'of', 'Spades')
# 102 -> ('Queen', 'of', 'Hearts')
# 103 -> ('Queen', 'of', 'Hearts')
# 104 -> ('Jack', 'of', 'Diamonds')
# 105 -> (3, 'of', 'Spades')
# 106 -> ('Ace', 'of', 'Diamonds')
# 107 -> (8, 'of', 'Hearts')
# 108 -> (4, 'of', 'Clubs')
# 109 -> ('King', 'of', 'Spades')
# 110 -> (4, 'of', 'Diamonds')
# 111 -> ('King', 'of', 'Spades')
# 112 -> ('Jack', 'of', 'Diamonds')
# 113 -> (9, 'of', 'Clubs')
# 114 -> ('King', 'of', 'Spades')
# 115 -> ('King', 'of', 'Clubs')
# 116 -> (10, 'of', 'Hearts')
# 117 -> (4, 'of', 'Clubs')
# 118 -> (9, 'of', 'Clubs')
# 119 -> (8, 'of', 'Diamonds')
# 120 -> (5, 'of', 'Spades')
# 121 -> ('Ace', 'of', 'Clubs')
# 122 -> (6, 'of', 'Clubs')
# 123 -> (2, 'of', 'Hearts')
# 124 -> ('Jack', 'of', 'Clubs')
# 125 -> (4, 'of', 'Hearts')
# 126 -> (7, 'of', 'Spades')
# 127 -> (4, 'of', 'Diamonds')
# 128 -> ('Ace', 'of', 'Clubs')
# 129 -> ('Queen', 'of', 'Clubs')
# 130 -> ('Queen', 'of', 'Diamonds')
# 131 -> (6, 'of', 'Spades')
# 132 -> ('Queen', 'of', 'Hearts')
# 133 -> ('Jack', 'of', 'Diamonds')
# 134 -> ('Ace', 'of', 'Spades')
# 135 -> (5, 'of', 'Diamonds')
# 136 -> (8, 'of', 'Hearts')
# 137 -> ('King', 'of', 'Diamonds')
# 138 -> (4, 'of', 'Clubs')
# 139 -> ('Queen', 'of', 'Clubs')
# 140 -> ('Jack', 'of', 'Hearts')
# 141 -> ('Queen', 'of', 'Diamonds')
# 142 -> (5, 'of', 'Clubs')
# 143 -> (8, 'of', 'Hearts')
# 144 -> ('Jack', 'of', 'Clubs')
# 145 -> (5, 'of', 'Spades')
# 146 -> ('Jack', 'of', 'Clubs')
# 147 -> ('Ace', 'of', 'Clubs')
# 148 -> ('King', 'of', 'Hearts')
# 149 -> (6, 'of', 'Spades')
# 150 -> (2, 'of', 'Spades')
# 151 -> ('King', 'of', 'Spades')
# 152 -> (4, 'of', 'Diamonds')
# 153 -> ('Ace', 'of', 'Hearts')
# 154 -> ('Jack', 'of', 'Spades')
# 155 -> (7, 'of', 'Clubs')
# 156 -> ('Queen', 'of', 'Spades')
# 157 -> (6, 'of', 'Clubs')
# 158 -> (5, 'of', 'Diamonds')
# 159 -> (8, 'of', 'Spades')
# 160 -> (7, 'of', 'Diamonds')
# 161 -> ('Ace', 'of', 'Clubs')
# 162 -> (9, 'of', 'Diamonds')
# 163 -> (4, 'of', 'Spades')
# 164 -> ('Queen', 'of', 'Hearts')
# 165 -> ('Ace', 'of', 'Diamonds')
# 166 -> (5, 'of', 'Hearts')
# 167 -> (4, 'of', 'Clubs')
# 168 -> (8, 'of', 'Diamonds')
# 169 -> ('Queen', 'of', 'Hearts')
# 170 -> (7, 'of', 'Clubs')
# 171 -> ('Queen', 'of', 'Diamonds')
# 172 -> (3, 'of', 'Hearts')
# 173 -> (6, 'of', 'Spades')
# 174 -> ('Queen', 'of', 'Hearts')
# 175 -> (8, 'of', 'Diamonds')
# 176 -> (2, 'of', 'Diamonds')
# 177 -> (6, 'of', 'Diamonds')
# 178 -> ('King', 'of', 'Hearts')
# 179 -> ('Jack', 'of', 'Spades')
# 180 -> (3, 'of', 'Spades')
# 181 -> (5, 'of', 'Clubs')
# 182 -> (4, 'of', 'Diamonds')
# 183 -> ('King', 'of', 'Clubs')
# 184 -> (4, 'of', 'Hearts')
# 185 -> (10, 'of', 'Hearts')
# 186 -> (2, 'of', 'Spades')
# 187 -> (5, 'of', 'Spades')
# 188 -> ('Jack', 'of', 'Hearts')
# 189 -> ('Jack', 'of', 'Spades')
# 190 -> (5, 'of', 'Diamonds')
# 191 -> (5, 'of', 'Spades')
# 192 -> (10, 'of', 'Hearts')
# 193 -> ('Ace', 'of', 'Hearts')
# 194 -> (5, 'of', 'Diamonds')
# 195 -> ('Ace', 'of', 'Hearts')
# 196 -> ('King', 'of', 'Diamonds')
# 197 -> ('King', 'of', 'Spades')
# 198 -> ('King', 'of', 'Spades')
# 199 -> (9, 'of', 'Hearts')
# 200 -> (10, 'of', 'Hearts')
# 201 -> ('Jack', 'of', 'Diamonds')
# 202 -> (3, 'of', 'Diamonds')
# 203 -> ('Ace', 'of', 'Diamonds')
# 204 -> ('King', 'of', 'Clubs')
# 205 -> (5, 'of', 'Diamonds')
# 206 -> ('Jack', 'of', 'Clubs')
# 207 -> (2, 'of', 'Hearts')
# 208 -> ('King', 'of', 'Diamonds')
# 209 -> ('Queen', 'of', 'Clubs')
# 210 -> (4, 'of', 'Spades')
# 211 -> ('Jack', 'of', 'Hearts')
# 212 -> (9, 'of', 'Diamonds')
# 213 -> (4, 'of', 'Hearts')
# 214 -> (8, 'of', 'Diamonds')
# 215 -> (8, 'of', 'Spades')
# 216 -> ('Queen', 'of', 'Clubs')
# 217 -> ('Queen', 'of', 'Spades')
# 218 -> ('Jack', 'of', 'Clubs')
# 219 -> ('Queen', 'of', 'Diamonds')
# 220 -> (8, 'of', 'Diamonds')
# 221 -> (7, 'of', 'Hearts')
# 222 -> ('Jack', 'of', 'Clubs')
# 223 -> (3, 'of', 'Hearts')
# 224 -> (8, 'of', 'Hearts')
# 225 -> (6, 'of', 'Diamonds')
# 226 -> (5, 'of', 'Spades')
# 227 -> (8, 'of', 'Diamonds')
# 228 -> ('Queen', 'of', 'Clubs')
# 229 -> ('Ace', 'of', 'Clubs')
# 230 -> (10, 'of', 'Clubs')
# 231 -> (6, 'of', 'Hearts')
# 232 -> ('Queen', 'of', 'Spades')
# 233 -> ('King', 'of', 'Diamonds')
# 234 -> (8, 'of', 'Hearts')
# 235 -> (2, 'of', 'Hearts')
# 236 -> (10, 'of', 'Diamonds')
# 237 -> ('Jack', 'of', 'Spades')
# 238 -> ('Queen', 'of', 'Diamonds')
# 239 -> ('Queen', 'of', 'Hearts')
# 240 -> (4, 'of', 'Clubs')
# 241 -> ('Queen', 'of', 'Diamonds')
# 242 -> (7, 'of', 'Diamonds')
# 243 -> ('Queen', 'of', 'Diamonds')
# 244 -> (6, 'of', 'Spades')
# 245 -> ('Ace', 'of', 'Diamonds')
# 246 -> (3, 'of', 'Spades')
# 247 -> (10, 'of', 'Clubs')
# 248 -> (6, 'of', 'Clubs')
# 249 -> ('King', 'of', 'Clubs')
# 250 -> ('King', 'of', 'Spades')
# 251 -> (5, 'of', 'Spades')
# 252 -> ('King', 'of', 'Hearts')
# 253 -> ('Jack', 'of', 'Diamonds')
# 254 -> ('King', 'of', 'Diamonds')
# 255 -> (2, 'of', 'Clubs')
# 256 -> (7, 'of', 'Hearts')
# 257 -> (2, 'of', 'Diamonds')
# 258 -> (10, 'of', 'Hearts')
# 259 -> (9, 'of', 'Spades')
# 260 -> ('Ace', 'of', 'Clubs')
# 261 -> (5, 'of', 'Spades')
# 262 -> (10, 'of', 'Spades')
# 263 -> (8, 'of', 'Diamonds')
# 264 -> (5, 'of', 'Diamonds')
# 265 -> (8, 'of', 'Spades')
# 266 -> ('Jack', 'of', 'Clubs')
# 267 -> (2, 'of', 'Hearts')
# 268 -> (7, 'of', 'Clubs')
# 269 -> (5, 'of', 'Hearts')
# 270 -> ('Queen', 'of', 'Hearts')
# 271 -> (3, 'of', 'Diamonds')
# 272 -> ('Jack', 'of', 'Diamonds')
# 273 -> ('King', 'of', 'Spades')
# 274 -> ('King', 'of', 'Clubs')
# 275 -> (8, 'of', 'Hearts')
# 276 -> (8, 'of', 'Hearts')
# 277 -> ('Ace', 'of', 'Clubs')
# 278 -> (3, 'of', 'Spades')
# 279 -> (5, 'of', 'Diamonds')
# 280 -> ('King', 'of', 'Clubs')
# 281 -> ('King', 'of', 'Diamonds')
# 282 -> ('Jack', 'of', 'Clubs')
# 283 -> (3, 'of', 'Diamonds')
# 284 -> (10, 'of', 'Clubs')
# 285 -> ('King', 'of', 'Clubs')
# 286 -> (2, 'of', 'Spades')
# 287 -> ('King', 'of', 'Clubs')
# 288 -> ('Jack', 'of', 'Hearts')
# 289 -> ('Jack', 'of', 'Clubs')
# 290 -> ('Queen', 'of', 'Diamonds')
# 291 -> ('Jack', 'of', 'Diamonds')
# 292 -> ('Queen', 'of', 'Clubs')
# 293 -> (3, 'of', 'Clubs')
# 294 -> ('Queen', 'of', 'Clubs')
# 295 -> (10, 'of', 'Hearts')
# 296 -> ('Ace', 'of', 'Spades')
# 297 -> (9, 'of', 'Clubs')
# 298 -> ('Queen', 'of', 'Hearts')
# 299 -> (10, 'of', 'Spades')
# 300 -> ('Queen', 'of', 'Diamonds')
# 301 -> (10, 'of', 'Hearts')
# 302 -> ('King', 'of', 'Spades')
# 303 -> (7, 'of', 'Hearts')
# 304 -> ('Queen', 'of', 'Spades')
# 305 -> (9, 'of', 'Hearts')
# 306 -> ('Queen', 'of', 'Clubs')
# 307 -> ('Jack', 'of', 'Hearts')
# 308 -> (6, 'of', 'Spades')
# 309 -> ('Queen', 'of', 'Hearts')
# 310 -> ('King', 'of', 'Clubs')
# 311 -> (6, 'of', 'Diamonds')
# 312 -> (7, 'of', 'Diamonds')
# 313 -> (5, 'of', 'Clubs')
# 314 -> ('Jack', 'of', 'Diamonds')
# 315 -> ('Queen', 'of', 'Clubs')
# 316 -> ('King', 'of', 'Diamonds')
# 317 -> ('Ace', 'of', 'Spades')
# 318 -> (7, 'of', 'Hearts')
# 319 -> (10, 'of', 'Diamonds')
# 320 -> ('Jack', 'of', 'Diamonds')
# 321 -> ('Jack', 'of', 'Diamonds')
# 322 -> ('King', 'of', 'Diamonds')
# 323 -> (3, 'of', 'Hearts')
# 324 -> ('Jack', 'of', 'Spades')
# 325 -> (6, 'of', 'Diamonds')
# 326 -> ('Jack', 'of', 'Clubs')
# 327 -> (10, 'of', 'Spades')
# 328 -> ('Jack', 'of', 'Hearts')
# 329 -> ('King', 'of', 'Hearts')
# 330 -> ('King', 'of', 'Diamonds')
# 331 -> ('Queen', 'of', 'Diamonds')
# 332 -> (6, 'of', 'Hearts')
# 333 -> (3, 'of', 'Spades')
# 334 -> (5, 'of', 'Spades')
# 335 -> ('Jack', 'of', 'Hearts')
# 336 -> ('Queen', 'of', 'Clubs')
# 337 -> (9, 'of', 'Hearts')
# 338 -> (8, 'of', 'Hearts')
# 339 -> (2, 'of', 'Spades')
# 340 -> ('Ace', 'of', 'Spades')
# 341 -> ('Queen', 'of', 'Diamonds')
# 342 -> (7, 'of', 'Diamonds')
# 343 -> ('Jack', 'of', 'Spades')
# 344 -> (5, 'of', 'Spades')
# 345 -> ('Ace', 'of', 'Spades')
# 346 -> (3, 'of', 'Spades')
# 347 -> (10, 'of', 'Clubs')
# 348 -> (2, 'of', 'Diamonds')
# 349 -> (6, 'of', 'Clubs')
# 350 -> ('Ace', 'of', 'Hearts')
# 351 -> ('Queen', 'of', 'Hearts')
# 352 -> ('Jack', 'of', 'Hearts')
# 353 -> (3, 'of', 'Diamonds')
# 354 -> ('Ace', 'of', 'Spades')
# 355 -> ('Queen', 'of', 'Hearts')
# 356 -> ('Jack', 'of', 'Clubs')
# 357 -> ('Jack', 'of', 'Spades')
# 358 -> (8, 'of', 'Diamonds')
# 359 -> (7, 'of', 'Clubs')
# 360 -> ('Queen', 'of', 'Spades')
# 361 -> ('Jack', 'of', 'Clubs')
# 362 -> (4, 'of', 'Hearts')
# 363 -> (5, 'of', 'Hearts')
# 364 -> ('King', 'of', 'Spades')
# 365 -> ('Jack', 'of', 'Clubs')
# 366 -> (10, 'of', 'Spades')
# 367 -> ('Jack', 'of', 'Diamonds')
# 368 -> (2, 'of', 'Spades')
# 369 -> (5, 'of', 'Diamonds')
# 370 -> (4, 'of', 'Spades')
# 371 -> ('Jack', 'of', 'Diamonds')
# 372 -> (7, 'of', 'Clubs')
# 373 -> (9, 'of', 'Clubs')
# 374 -> (3, 'of', 'Spades')
# 375 -> (3, 'of', 'Diamonds')
# 376 -> ('Jack', 'of', 'Hearts')
# 377 -> ('Queen', 'of', 'Clubs')
# 378 -> ('Queen', 'of', 'Spades')
# 379 -> (9, 'of', 'Hearts')
# 380 -> (10, 'of', 'Diamonds')
# 381 -> (4, 'of', 'Spades')
# 382 -> ('King', 'of', 'Clubs')
# 383 -> ('King', 'of', 'Diamonds')
# 384 -> (5, 'of', 'Clubs')
# 385 -> (3, 'of', 'Clubs')
# 386 -> (5, 'of', 'Spades')
# 387 -> (4, 'of', 'Spades')
# 388 -> ('Queen', 'of', 'Hearts')
# 389 -> (3, 'of', 'Spades')
# 390 -> ('Queen', 'of', 'Hearts')
# 391 -> ('Ace', 'of', 'Clubs')
# 392 -> ('King', 'of', 'Spades')
# 393 -> (7, 'of', 'Diamonds')
# 394 -> ('Jack', 'of', 'Diamonds')
# 395 -> (8, 'of', 'Spades')
# 396 -> (2, 'of', 'Diamonds')
# 397 -> (6, 'of', 'Clubs')
# 398 -> ('Jack', 'of', 'Diamonds')
# 399 -> ('Queen', 'of', 'Clubs')
# 400 -> ('Jack', 'of', 'Spades')
# 401 -> (2, 'of', 'Spades')
# 402 -> ('Ace', 'of', 'Hearts')
# 403 -> (6, 'of', 'Clubs')
# 404 -> ('Ace', 'of', 'Diamonds')
# 405 -> ('Ace', 'of', 'Hearts')
# 406 -> ('Jack', 'of', 'Clubs')
# 407 -> ('Ace', 'of', 'Clubs')
# 408 -> ('King', 'of', 'Diamonds')
# 409 -> ('King', 'of', 'Diamonds')
# 410 -> (8, 'of', 'Hearts')
# 411 -> ('Queen', 'of', 'Hearts')
# 412 -> (9, 'of', 'Spades')
# 413 -> (9, 'of', 'Diamonds')
# 414 -> (5, 'of', 'Spades')
# 415 -> ('Jack', 'of', 'Spades')
# 416 -> (9, 'of', 'Hearts')
# 417 -> ('King', 'of', 'Spades')
# 418 -> (7, 'of', 'Diamonds')
# 419 -> (5, 'of', 'Spades')
# 420 -> ('Queen', 'of', 'Diamonds')
# 421 -> (2, 'of', 'Clubs')
# 422 -> (3, 'of', 'Hearts')
# 423 -> ('Queen', 'of', 'Spades')
# 424 -> ('Jack', 'of', 'Clubs')
# 425 -> ('Ace', 'of', 'Spades')
# 426 -> (10, 'of', 'Diamonds')
# 427 -> ('King', 'of', 'Clubs')
# 428 -> (4, 'of', 'Clubs')
# 429 -> (5, 'of', 'Clubs')
# 430 -> ('Queen', 'of', 'Clubs')
# 431 -> (4, 'of', 'Spades')
# 432 -> ('Jack', 'of', 'Diamonds')
# 433 -> (9, 'of', 'Hearts')
# 434 -> ('King', 'of', 'Diamonds')
# 435 -> (6, 'of', 'Spades')
# 436 -> (10, 'of', 'Spades')
# 437 -> (9, 'of', 'Spades')
# 438 -> (2, 'of', 'Hearts')
# 439 -> ('King', 'of', 'Diamonds')
# 440 -> (10, 'of', 'Clubs')
# 441 -> ('Queen', 'of', 'Spades')
# 442 -> (4, 'of', 'Spades')
# 443 -> (2, 'of', 'Spades')
# 444 -> (7, 'of', 'Clubs')
# 445 -> (3, 'of', 'Hearts')
# 446 -> ('Ace', 'of', 'Spades')
# 447 -> ('Ace', 'of', 'Hearts')
# 448 -> ('Queen', 'of', 'Spades')
# 449 -> ('Jack', 'of', 'Diamonds')
# 450 -> ('Ace', 'of', 'Spades')
# 451 -> (4, 'of', 'Clubs')
# 452 -> (7, 'of', 'Diamonds')
# 453 -> ('King', 'of', 'Hearts')
# 454 -> ('Ace', 'of', 'Spades')
# 455 -> ('Queen', 'of', 'Hearts')
# 456 -> ('Queen', 'of', 'Clubs')
# 457 -> (8, 'of', 'Spades')
# 458 -> ('Queen', 'of', 'Clubs')
# 459 -> ('Ace', 'of', 'Spades')
# 460 -> (9, 'of', 'Hearts')
# 461 -> (10, 'of', 'Hearts')
# 462 -> ('Ace', 'of', 'Clubs')
# 463 -> (2, 'of', 'Clubs')
# 464 -> ('King', 'of', 'Spades')
# 465 -> ('Queen', 'of', 'Spades')
# 466 -> (8, 'of', 'Clubs')
# 467 -> (2, 'of', 'Hearts')
# 468 -> (9, 'of', 'Hearts')
# 469 -> ('King', 'of', 'Hearts')
# 470 -> (5, 'of', 'Clubs')
# 471 -> ('Jack', 'of', 'Clubs')
# 472 -> ('Jack', 'of', 'Hearts')
# 473 -> (10, 'of', 'Spades')
# 474 -> ('King', 'of', 'Hearts')
# 475 -> ('Queen', 'of', 'Clubs')
# 476 -> ('Jack', 'of', 'Spades')
# 477 -> ('Ace', 'of', 'Hearts')
# 478 -> ('Queen', 'of', 'Diamonds')
# 479 -> (10, 'of', 'Clubs')
# 480 -> ('Queen', 'of', 'Diamonds')
# 481 -> ('King', 'of', 'Diamonds')
# 482 -> ('Ace', 'of', 'Diamonds')
# 483 -> (7, 'of', 'Diamonds')
# 484 -> ('King', 'of', 'Hearts')
# 485 -> (7, 'of', 'Diamonds')
# 486 -> (7, 'of', 'Diamonds')
# 487 -> (6, 'of', 'Clubs')
# 488 -> (9, 'of', 'Clubs')
# 489 -> (10, 'of', 'Spades')
# 490 -> ('Queen', 'of', 'Hearts')
# 491 -> ('King', 'of', 'Clubs')
# 492 -> ('Ace', 'of', 'Diamonds')
# 493 -> ('Ace', 'of', 'Hearts')
# 494 -> ('Ace', 'of', 'Hearts')
# 495 -> ('King', 'of', 'Diamonds')
# 496 -> ('Queen', 'of', 'Clubs')
# 497 -> ('Ace', 'of', 'Diamonds')
# 498 -> (6, 'of', 'Hearts')
# 499 -> ('King', 'of', 'Spades')

# %%
deck = set()
for suit in suits: 
    for card in faces + numbered:
        deck.add(f"{card} of {suit}")

# %%
len(deck)
# Out:
# 52

# %%
print(dir(card))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']

# %%
def draw():
    card = random.choice(list(deck))
    deck.remove(card)
    return card

# %%
draw()
# Out:
# 'King of Spades'

# %%
deck = set()
for suit in suits:
    for card in faces + numbered:
        deck.add(f"{card} of {suit}")

# %%
len(deck)
# Out:
# 52

# %%
for _ in range(5):
    print(draw())
# Out:
# Jack of Clubs
# 7 of Diamonds
# 5 of Hearts
# Queen of Diamonds
# 8 of Hearts

# %%
len(deck)
# Out:
# 47
